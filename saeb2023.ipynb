# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df_ts_item = pd.read_csv('TS_ITEM.csv', sep=';', encoding='latin-1')

# %%
df_ts_item.head(10)
# Out:
#    ID_SAEB  ID_SERIE TP_DISCIPLINA  NU_BLOCO  NU_POSICAO ID_ITEM  \
# 0     2023         2            LP         1           1  131475
# 1     2023         2            LP         1           1  135800
# 2     2023         2            LP         1           1  143333
# 3     2023         2            LP         1           2  117433
# 4     2023         2            LP         1           3  132263
# 5     2023         2            LP         1           4  133034
# 6     2023         2            LP         1           5  117324
# 7     2023         2            LP         1           6  132405
# 8     2023         2            LP         1           7  132042
# 9     2023         2            LP         1           8  117538
#
#   NU_DESCRITOR_HABILIDADE TX_GABARITO              TP_ITEM TP_ITEM_MODELO  \
# 0                      H4           D    Resposta Objetiva           M3PL
# 1                    H3.1         A/B  Resposta Construída            MRG
# ...

# %%
COLUNAS_SAEB_59ef = [
    'ID_ALUNO', 'ID_REGIAO', 'ID_UF', 'ID_MUNICIPIO', 'ID_ESCOLA',
    'IN_PUBLICA', 'ID_LOCALIZACAO', 'ID_SERIE',
    'PROFICIENCIA_LP_SAEB', 'PROFICIENCIA_MT_SAEB', 
    'PROFICIENCIA_CH_SAEB','PROFICIENCIA_CN_SAEB', 'INSE_ALUNO'
]

COLUNAS_SAEB_34em = [
    'ID_ALUNO', 'ID_REGIAO', 'ID_UF', 'ID_MUNICIPIO', 'ID_ESCOLA',
    'IN_PUBLICA', 'ID_LOCALIZACAO', 'ID_SERIE',
    'PROFICIENCIA_LP_SAEB', 'PROFICIENCIA_MT_SAEB','IN_PROFICIENCIA_LP', 'INSE_ALUNO'
]

# %%
df_34EM = pd.read_csv('TS_ALUNO_34EM.csv', sep=';', encoding='latin-1', usecols=COLUNAS_SAEB_34em)

# %%
df_34EM
# Out:
#          ID_REGIAO  ID_UF  ID_MUNICIPIO  ID_ESCOLA  IN_PUBLICA  \
# 0                1     11       6322170   61412274           1
# 1                1     11       6322170   61412274           1
# 2                1     11       6322170   61412274           1
# 3                1     11       6322170   61412274           1
# 4                1     11       6322170   61412274           1
# ...            ...    ...           ...        ...         ...
# 2091332          5     53       6327738   61470349           1
# 2091333          5     53       6327738   61470349           1
# 2091334          5     53       6327738   61470349           1
# 2091335          5     53       6327738   61470349           1
# 2091336          5     53       6327738   61470349           1
#
#          ID_LOCALIZACAO  ID_SERIE  ID_ALUNO  IN_PROFICIENCIA_LP  \
# 0                     1        12  49408512                   1
# 1                     1        12  49408513                   1
# ...

# %%
df_0 = df_34EM[df_34EM['IN_PROFICIENCIA_LP'] == 0]
len(df_0)
# Out:
# 565380

# %%
df_34EM.isnull().sum()
# Out:
# ID_REGIAO                    0
# ID_UF                        0
# ID_MUNICIPIO                 0
# ID_ESCOLA                    0
# IN_PUBLICA                   0
# ID_LOCALIZACAO               0
# ID_SERIE                     0
# ID_ALUNO                     0
# IN_PROFICIENCIA_LP           0
# PROFICIENCIA_LP_SAEB    565380
# PROFICIENCIA_MT_SAEB    565380
# INSE_ALUNO              654785
# dtype: int64

# %%
df_34EM = df_34EM[~df_34EM['PROFICIENCIA_LP_SAEB'].isna()]
df_34EM
# Out:
#          ID_REGIAO  ID_UF  ID_MUNICIPIO  ID_ESCOLA  IN_PUBLICA  \
# 0                1     11       6322170   61412274           1
# 1                1     11       6322170   61412274           1
# 2                1     11       6322170   61412274           1
# 3                1     11       6322170   61412274           1
# 4                1     11       6322170   61412274           1
# ...            ...    ...           ...        ...         ...
# 2091328          5     53       6327738   61470349           1
# 2091329          5     53       6327738   61470349           1
# 2091330          5     53       6327738   61470349           1
# 2091331          5     53       6327738   61470349           1
# 2091332          5     53       6327738   61470349           1
#
#          ID_LOCALIZACAO  ID_SERIE  ID_ALUNO  IN_PROFICIENCIA_LP  \
# 0                     1        12  49408512                   1
# 1                     1        12  49408513                   1
# ...
